# %%
from bs4 import BeautifulSoup
import requests
import glob
import re

# %%
url = "https://dpul.princeton.edu/slavic/catalog/n870zv76g"
s = requests.get(url)
soup = BeautifulSoup(s.content)

# %%
print (soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Vestnik iskusstv : organ Khudozhestvennogo otdela Glavpolitprosveta - Digital PUL</title>
# <link href="https://dpul.princeton.edu/slavic/catalog/opensearch.xml" rel="search" title="Vestnik iskusstv : organ Khudozhestvennogo otdela Glavpolitprosveta - Digital PUL" type="application/opensearchdescription+xml"/>
# <link href="/assets/favicon-0a7e6b0863403f2f8ac53d5867efc7aa22abf57ca74cebae2d8c9cf1907d4da6.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/packs/js/application-fec695282dbf2e0ec926.js"></script>
# <link href="https://use.typekit.net/yhr7zwc.css" rel="stylesheet"/>
# <link href="/packs/css/application-e498fbaa.css" media="screen" rel="stylesheet"/>
# ...
